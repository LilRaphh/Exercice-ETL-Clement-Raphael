# %% [markdown]
# # Importation des modules nécessaires

# %%
from Extract.API import API
from Extract.Scrapping import Scrapping
from Transform.TransformData import TransformData   
import pandas as pd

# %% [markdown]
# # Récupération de la donnée (via api)

# %%
# Utiliser l'API pour récupérer les données vélo/piéton
api = API()

# Lien de l'API qui retourne un CSV
lien_api_velo_pieton = (
    "https://data.rennesmetropole.fr/api/explore/v2.1/catalog/datasets/"
    "eco-counter-data/exports/csv?lang=fr&timezone=Europe%2FBerlin&"
    "use_labels=true&delimiter=%3B"
)

# Récupérer toutes les données au format CSV
csv_pieton_velo_rennes = api.get_api_data(lien_api_velo_pieton)

# Vérifier et afficher les données récupérées
if csv_pieton_velo_rennes is not None:
    print(f"Total d'enregistrements récupérés : {len(csv_pieton_velo_rennes)}")
else:
    print("Aucune donnée récupérée.")

df_velo_piton = pd.DataFrame(csv_pieton_velo_rennes)
df_velo_piton.head()
# Out:
# Les données ont été chargées avec succès.
# Total d'enregistrements récupérés : 137362
#                         date                   isoDate  counts  status  \
# 0  2017-02-16T10:00:00+01:00  2017-02-16T09:00:00+0100     6.0     0.0
# 1  2017-02-16T13:00:00+01:00  2017-02-16T12:00:00+0100    18.0     0.0
# 2  2017-02-16T14:00:00+01:00  2017-02-16T13:00:00+0100    11.0     0.0
# 3  2017-02-16T17:00:00+01:00  2017-02-16T16:00:00+0100    31.0     0.0
# 4  2017-02-16T20:00:00+01:00  2017-02-16T19:00:00+0100    18.0     0.0
#
#           ID                        name counter  \
# 0  100017942  Boulevard Georges Pompidou     NaN
# 1  100017942  Boulevard Georges Pompidou     NaN
# 2  100017942  Boulevard Georges Pompidou     NaN
# 3  100017942  Boulevard Georges Pompidou     NaN
# 4  100017942  Boulevard Georges Pompidou     NaN
#
#                                    geo  sens
# 0  48.1014223209623, -1.68490237617492     5
# 1  48.1014223209623, -1.68490237617492     5
# 2  48.1014223209623, -1.68490237617492     5
# 3  48.1014223209623, -1.68490237617492     5
# 4  48.1014223209623, -1.68490237617492     5

# %% [markdown]
# # Récupération de la data (via scrapping)

# %%
# Importation de notre class de scraping 
scrap = Scrapping()

# %% [markdown]
# ### Scrap toute les datas d'aujourd'hui

# %%
col, data = scrap.scrap_site()

df_meteo_aujourdhui = pd.DataFrame(data, columns=col)
df_meteo_aujourdhui.head()
# Out:
#   Heure locale\naccess_time\n30mn\nMETAR                      \
# 0                    2024-11-15 11:00:00  add_circle_outline
# 1                    2024-11-15 10:00:00  add_circle_outline
# 2                    2024-11-15 09:00:00  add_circle_outline
# 3                    2024-11-15 08:00:00  add_circle_outline
# 4                    2024-11-15 07:00:00  add_circle_outline
#
#          Température Temps    Pluie             Vent Humidité    Bio-météo  \
# 0  6.9 °C\n4.2 → 7.6        0 mm/1h  4 km/h\nraf.9.4     100%  6.8\n\n203
# 1  4.1 °C\n2.4 → 4.1        0 mm/1h  0 km/h\nraf.5.8     100%   4.1\n\n78
# 2    2.5 °C\n2.5 → 3        0 mm/1h  4 km/h\nraf.5.8     100%    1.9\n\n8
# 3    3.1 °C\n3 → 4.3        0 mm/1h  7 km/h\nraf.7.6     100%          1.1
# 4  4.1 °C\n4.1 → 4.5        0 mm/1h  0 km/h\nraf.5.8      99%          4.1
#
#   Pt. de rosée        Pression Visibilité
# 0       6.9 °C       1027.9hPa      300 m
# 1       4.1 °C  1028.0hPa\n\n=      100 m
# 2       2.5 °C       1028.0hPa      100 m
# 3       3.1 °C       1027.9hPa      100 m
# 4         4 °C       1028.0hPa      200 m

# %% [markdown]
# ### Scrap à partir d'une date

# %%
# Scrap à partir de x date et renvoie un csv dans dataset et renvoie un dataframe 
df_meteo_date = scrap.scrap_with_start_date('2024-11-12')

df_meteo_date.head()
# Out:
# La page du 12 novembre 2024 a été scrap !
# La page du 13 novembre 2024 a été scrap !
# La page du 14 novembre 2024 a été scrap !
#   Heure locale\naccess_time\n30mn\nMETAR                      \
# 0                    2024-11-12 00:00:00  add_circle_outline
# 1                    2024-11-12 23:00:00  add_circle_outline
# 2                    2024-11-12 22:00:00  add_circle_outline
# 3                    2024-11-12 21:00:00  add_circle_outline
# 4                    2024-11-12 20:00:00  add_circle_outline
#
#             Température Temps    Pluie                 Vent Humidité  \
# 0     8.4 °C\n8.4 → 8.9        0 mm/1h    14 km/h\nraf.29.9      79%
# 1     8.7 °C\n8.5 → 9.3        0 mm/1h    14 km/h\nraf.28.4      80%
# 2    9.3 °C\n9.3 → 10.3        0 mm/1h    18 km/h\n\nraf.32      76%
# 3  10.3 °C\n10.3 → 10.7        0 mm/1h  11 km/h\n\nraf.31.3      72%
# 4  10.4 °C\n10.1 → 10.7        0 mm/1h  18 km/h\n\nraf.30.6      73%
#
#   Bio-météo Pt. de rosée   Pression Visibilité
# 0       5.9         5 °C  1030.8hPa      26 km
# 1       6.3       5.4 °C  1031.0hPa      25 km
# 2       6.6       5.3 °C  1030.6hPa      30 km
# 3                 5.5 °C  1030.4hPa      35 km
# 4                 5.8 °C  1030.0hPa      40 km

# %% [markdown]
# # Transformation de la data

# %%
df_meteo = pd.read_csv("./dataset/meteo_rennes.csv")
df_meteo.head()
# Out:
#    Unnamed: 0 Heure locale\naccess_time\n30mn\nMETAR          Unnamed: 2  \
# 0           0                    2023-01-01 00:00:00  add_circle_outline
# 1           1                    2023-01-01 23:00:00  add_circle_outline
# 2           2                    2023-01-01 22:00:00  add_circle_outline
# 3           3                    2023-01-01 21:00:00  add_circle_outline
# 4           4                    2023-01-01 20:00:00  add_circle_outline
#
#             Température Temps    Pluie                 Vent Humidité  \
# 0     9.5 °C\n9.5 → 9.9   NaN  0 mm/1h     7 km/h\nraf.10.8      94%
# 1    9.9 °C\n9.9 → 10.5   NaN  0 mm/1h     7 km/h\nraf.28.8      94%
# 2  10.5 °C\n10.5 → 13.1   NaN  0 mm/1h  22 km/h\n\nraf.42.5      91%
# 3    13.1 °C\n13 → 13.4   NaN  0 mm/1h  22 km/h\n\nraf.39.2      89%
# 4    13.0 °C\n12.1 → 13   NaN  0 mm/1h  18 km/h\n\nraf.34.9      89%
#
#   Bio-météo Pt. de rosée   Pression Visibilité
# 0       8.5       8.6 °C  1013.3hPa      60 km
# 1         9         9 °C  1012.8hPa      60 km
# 2       NaN       9.1 °C  1011.6hPa      60 km
# 3       NaN      11.3 °C  1010.1hPa      14 km
# 4       NaN      11.2 °C  1008.6hPa      30 km

# %%
transform = TransformData()

df_meteo = transform.remove_currency_symbols(df_meteo, ['Humidité', 'Pression', 'Visibilité', 'Température', 'Pluie', 'Vent', 'Pt. de rosée'])

df_meteo = transform.rename_column(df_meteo, 'Heure locale\naccess_time\n30mn\nMETAR', 'date')
df_meteo = transform.rename_column(df_meteo, 'Température', 'Température (°C)')
df_meteo = transform.rename_column(df_meteo, 'Pluie', 'Pluie (mm/h)')
df_meteo = transform.rename_column(df_meteo, 'Humidité', 'Humidité (%)')
df_meteo = transform.rename_column(df_meteo, 'Pt. de rosée', 'Point_rosé (°C)')
df_meteo = transform.rename_column(df_meteo, 'Pression', 'Pression (hPa)')
df_meteo = transform.rename_column(df_meteo, 'Visibilité', 'Visibilité (km)')
df_meteo = transform.rename_column(df_meteo, 'Vent', 'Vent (km/h)')

df_meteo = transform.remove_column(df_meteo, ['Unnamed: 0', 'Unnamed: 2', 'Temps', 'Bio-météo'])

df_meteo.head()
# Out:
# Traitement de la colonne: Humidité
# Traitement de la colonne: Pression
# Traitement de la colonne: Visibilité
# Traitement de la colonne: Température
# Traitement de la colonne: Pluie
# Traitement de la colonne: Vent
# Traitement de la colonne: Pt. de rosée
#                   date Température (°C) Pluie (mm/h) Vent (km/h) Humidité (%)  \
# 0  2023-01-01 00:00:00              9.5            0           7           94
# 1  2023-01-01 23:00:00              9.9            0           7           94
# 2  2023-01-01 22:00:00             10.5            0          22           91
# 3  2023-01-01 21:00:00             13.1            0          22           89
# 4  2023-01-01 20:00:00             13.0            0          18           89
#
#   Point_rosé (°C) Pression (hPa) Visibilité (km)
# 0             8.6         1013.3              60
# 1               9         1012.8              60
# 2             9.1         1011.6              60
# 3            11.3         1010.1              14
# 4            11.2         1008.6              30

# %%
# Convertir les colonnes 'date' en format datetime sans décalage horaire pour les deux DataFrames
df_velo_piton['date'] = pd.to_datetime(df_velo_piton['date'], utc=True).dt.tz_convert(None)
df_meteo['date'] = pd.to_datetime(df_meteo['date'], utc=True).dt.tz_convert(None)

# Effectuer la jointure
df_merged = pd.merge(df_velo_piton, df_meteo, on='date', how='left')
df_merged.head()
# Out:
#                  date                   isoDate  counts  status         ID  \
# 0 2017-02-16 09:00:00  2017-02-16T09:00:00+0100     6.0     0.0  100017942
# 1 2017-02-16 12:00:00  2017-02-16T12:00:00+0100    18.0     0.0  100017942
# 2 2017-02-16 13:00:00  2017-02-16T13:00:00+0100    11.0     0.0  100017942
# 3 2017-02-16 16:00:00  2017-02-16T16:00:00+0100    31.0     0.0  100017942
# 4 2017-02-16 19:00:00  2017-02-16T19:00:00+0100    18.0     0.0  100017942
#
#                          name counter                                  geo  \
# 0  Boulevard Georges Pompidou     NaN  48.1014223209623, -1.68490237617492
# 1  Boulevard Georges Pompidou     NaN  48.1014223209623, -1.68490237617492
# 2  Boulevard Georges Pompidou     NaN  48.1014223209623, -1.68490237617492
# 3  Boulevard Georges Pompidou     NaN  48.1014223209623, -1.68490237617492
# 4  Boulevard Georges Pompidou     NaN  48.1014223209623, -1.68490237617492
#
#    sens Température (°C) Pluie (mm/h) Vent (km/h) Humidité (%)  \
# 0     5              NaN          NaN         NaN          NaN
# 1     5              NaN          NaN         NaN          NaN
# 2     5              NaN          NaN         NaN          NaN
# 3     5              NaN          NaN         NaN          NaN
# 4     5              NaN          NaN         NaN          NaN
#
#   Point_rosé (°C) Pression (hPa) Visibilité (km)
# 0             NaN            NaN             NaN
# 1             NaN            NaN             NaN
# 2             NaN            NaN             NaN
# 3             NaN            NaN             NaN
# 4             NaN            NaN             NaN

# %%
df_merged = transform.remove_column(df_merged, ['status', 'ID', 'geo', 'counter', 'sens'])

df_merged.head()
# Out:
#                  date                   isoDate  counts  \
# 0 2017-02-16 09:00:00  2017-02-16T09:00:00+0100     6.0
# 1 2017-02-16 12:00:00  2017-02-16T12:00:00+0100    18.0
# 2 2017-02-16 13:00:00  2017-02-16T13:00:00+0100    11.0
# 3 2017-02-16 16:00:00  2017-02-16T16:00:00+0100    31.0
# 4 2017-02-16 19:00:00  2017-02-16T19:00:00+0100    18.0
#
#                          name Température (°C) Pluie (mm/h) Vent (km/h)  \
# 0  Boulevard Georges Pompidou              NaN          NaN         NaN
# 1  Boulevard Georges Pompidou              NaN          NaN         NaN
# 2  Boulevard Georges Pompidou              NaN          NaN         NaN
# 3  Boulevard Georges Pompidou              NaN          NaN         NaN
# 4  Boulevard Georges Pompidou              NaN          NaN         NaN
#
#   Humidité (%) Point_rosé (°C) Pression (hPa) Visibilité (km)
# 0          NaN             NaN            NaN             NaN
# 1          NaN             NaN            NaN             NaN
# 2          NaN             NaN            NaN             NaN
# 3          NaN             NaN            NaN             NaN
# 4          NaN             NaN            NaN             NaN

# %%
# Suppression des lignes où la colonne 'Température (°C)' a une valeur NaN
df_cleaned = df_merged.dropna(subset=['Température (°C)'])
df_cleaned_all = df_cleaned.drop_duplicates(subset=['date'])

df_cleaned_all = transform.remove_column(df_cleaned_all, 'isoDate')
# Affichage des premières lignes pour vérifier le résultat
df_cleaned_all.head()
# Out:
#                      date  counts                           name  \
# 33391 2023-01-01 07:00:00     7.0  Eco-Display Place de Bretagne
# 33392 2023-01-01 09:00:00    12.0  Eco-Display Place de Bretagne
# 33393 2023-01-01 17:00:00    35.0  Eco-Display Place de Bretagne
# 33394 2023-01-02 09:00:00    65.0  Eco-Display Place de Bretagne
# 33395 2023-01-02 15:00:00   142.0  Eco-Display Place de Bretagne
#
#       Température (°C) Pluie (mm/h) Vent (km/h) Humidité (%) Point_rosé (°C)  \
# 33391             11.8            0          22           82             8.8
# 33392             11.3            0          18           84             8.7
# 33393             11.6            0          18           91            10.2
# 33394              7.9            0           7           98             7.6
# 33395             13.0            0          11           69             7.4
#
#       Pression (hPa) Visibilité (km)
# 33391         1014.1              17
# 33392         1014.1              40
# 33393         1008.7              28
# 33394         1019.2              35
# 33395         1022.4              55

# %%
df_cleaned_all.count()
# Out:
# date                16366
# counts              15920
# name                16366
# Température (°C)    16366
# Pluie (mm/h)        16366
# Vent (km/h)         16366
# Humidité (%)        16366
# Point_rosé (°C)     16366
# Pression (hPa)      16366
# Visibilité (km)     16366
# dtype: int64

# %% [markdown]
# # Visualisation des datas
